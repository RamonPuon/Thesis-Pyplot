# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
linear_data = np.array([1,2,3,4,5,6,7,8])
exponential_data = linear_data**2
plt.figure()
plt.plot(linear_data,'-o',exponential_data,'-o')
plt.legend(['Baseline', 'Competition', 'Us'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pH = pd.read_csv('ph.csv')

# %%
abs590 = [0.66,0.1975,0.0795,0.035,0.023]
desvabs590 = [0.072794231,
0.035910769,
0.021681405,
0.025548973,
0.002565801]
growth = pd.DataFrame({'Absorbance':abs590,'Desv':desvabs590})
growth
# Out:
#    Absorbance      Desv
# 0      0.6600  0.072794
# 1      0.1975  0.035911
# 2      0.0795  0.021681
# 3      0.0350  0.025549
# 4      0.0230  0.002566

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()  # set up the 2nd axis
ax2.plot(growth['Absorbance'], color = 'orange', marker='d')

bars = ax1.bar(xvals,pH['%Reduccion'],width=0.8,yerr=pH['Desv est'],align='center', linewidth=0, color='lightslategrey')
bars[1].set_color('#1F77B4')
ax2.set_xlabel('pH')
ax2.set_ylabel('OD 590 nm')
ax1.set_xlabel('pH')
plt.legend(['Optical Density'])
ax1.set_ylim(0,50)
ax2.set_ylim(0,0.95)
ax1.set_ylabel('Chromium Reduction (%)')
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
plt.hlines(0.73,1,2, colors = 'black')
plt.hlines(0.78,1,3, colors = 'black')
plt.hlines(0.83,1,4, colors = 'black')
plt.hlines(0.88,0,1, colors = 'black')
plt.vlines(1,0.7,0.73, colors = 'black')
plt.vlines(2,0.7,0.73, colors = 'black')
plt.vlines(1,0.75,0.78, colors = 'black')
plt.vlines(3,0.75,0.78, colors = 'black')

plt.vlines(1,0.8,0.83, colors = 'black')
plt.vlines(4,0.8,0.83, colors = 'black')

plt.vlines(0,0.85,0.88, colors = 'black')
plt.vlines(1,0.85,0.88, colors = 'black')

ax2.text(1.5,0.73,'*')
ax2.text(2,0.78,'**')
ax2.text(2.5,0.83,'***')
ax2.text(0.34,0.88,'****')

ax1.text(0,18,'23%', color='w',fontsize=11,ha = 'center')
ax1.text(1,27,'32%', color='w',fontsize=11,ha = 'center')
ax1.text(2,22,'27%', color='w',fontsize=11,ha = 'center')
ax1.text(3,19,'24%', color='w',fontsize=11,ha = 'center')
ax1.text(4,17,'22%', color='w',fontsize=11,ha = 'center')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(4, 17, '22%')

# %%
pH
# Out:
#    pH  Reduccion  %Reduccion     Error  Desv est
# 0  10   0.235071   23.507088  0.028739  2.873942
# 1   8   0.328409   32.840947  0.026995  2.699485
# 2   7   0.279862   27.986238  0.009378  0.937816
# 3   6   0.249306   24.930608  0.030445  3.044451
# 4   5   0.225455   22.545513  0.019572  1.957203

# %%
xvals = ['10','8','7','6','5']

# %%
plt.figure()
plt.bar(xvals,pH['%Reduccion'],width=0.5,yerr=pH['Desv est'])
ax = plt.gca()
ax.set_xlabel('pH')
ax.set_ylabel('Reduction Percentage')
ax.set_title('Chromium Reduction at different pH levels')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Chromium Reduction at different pH levels')

# %%
xvals
# Out:
# 0    10
# 1     8
# 2     7
# 3     6
# 4     5
# Name: pH, dtype: int64

# %%
temp = pd.read_csv('temp.csv')

# %%
abstemp = [0.143333333,
0.1745,
0.3555,
0.420666667,
]

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()  # set up the 2nd axis
ax2.plot(abstemp, color = 'orange', marker='d')
tempvals = ['25','30','37','42']

bars = ax1.bar(tempvals,temp['%Red'],width=0.8,yerr=temp['Desv est'],align='center', linewidth=0, color='lightslategrey')
bars[3].set_color('#1F77B4')
ax2.set_xlabel('Temperature (°C)')
ax2.set_ylabel('OD 590 nm')
ax1.set_xlabel('Temperature (°C)')
plt.legend(['Optical Density'])

ax1.set_ylabel('Chromium Reduction (%)')
for i, v in enumerate(temp['%Red']):
    ax1.text(v + 3, i + .25, str(v), color='white', fontweight='bold')
ax1.set_ylim(0,70)
ax2.set_ylim(0,0.6)

plt.hlines(0.45,2,3, colors = 'black')
plt.vlines(2,0.43,0.45, colors = 'black')
plt.vlines(3,0.43,0.45, colors = 'black')
ax2.text(2.5,0.45,'*')
ax1.text(0,19,'24%', color='w',fontsize=11,ha = 'center')


plt.hlines(0.48,1,3, colors = 'black')
plt.vlines(1,0.46,0.48, colors = 'black')
plt.vlines(3,0.46,0.48, colors = 'black')
ax2.text(2,0.48,'*')
ax1.text(1,25,'30%', color='w',fontsize=11,ha = 'center')


plt.hlines(0.51,0,3, colors = 'black')
plt.vlines(0,0.49,0.51, colors = 'black')
plt.vlines(3,0.49,0.51, colors = 'black')
ax2.text(1.4,0.51,'*')
ax1.text(2,31,'36%', color='w',fontsize=11,ha = 'center')

ax1.text(3,41,'46%', color='w', fontsize=11, ha='center')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(3, 41, '46%')

# %%
temp
# Out:
#    Temp   %Red  Desv est
# 0    25  24.58      1.37
# 1    30  30.31      2.10
# 2    37  36.22      1.15
# 3    42  46.21      0.80

# %%
plt.figure()
plt.bar(temp['Temp'],temp['%Red'],width=0.5,yerr=temp['Desv est'])
ax = plt.gca()
ax.set_xlabel('Temperature (°C)')
ax.set_ylabel('Reduction Percentage')
ax.set_title('Chromium Reduction at different Temperatures (°C)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Chromium Reduction at different Temperatures (°C)')

# %%
plt.figure()
bars = plt.bar(xvals,pH['%Reduccion'],width=0.8,align='center', linewidth=0, color='lightslategrey',yerr=pH['Desv est'])
bars[1].set_color('#1F77B4')

ax = plt.gca()
ax.set_xlabel('pH')
ax.set_ylabel('Reduction Percentage')
ax.set_title('Chromium Reduction at different pH levels')
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tempvals = ['25','30','37','42']
plt.figure()
bars = plt.bar(tempvals,temp['%Red'],width=0.8,align='center', linewidth=0, color='lightslategrey',yerr=temp['Desv est'])
bars[3].set_color('#1F77B4')

ax = plt.gca()
ax.set_xlabel('Temperature (°C)')
ax.set_ylabel('Reduction Percentage')
ax.set_title('Chromium Reduction at different temperatures')
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
electron = pd.read_csv("Electron.csv")

# %%
electron
# Out:
#       Donador     Exp 1     Exp 2  Promedio  Porcentaje     Error   Desv est
# 0     Glucosa  0.505795  0.490119  0.497957   49.795679  0.011085   1.108491
# 1  Acetato Na  0.468825  0.191700  0.330262   33.026207  0.195957  19.595692
# 2     Lactosa  0.580589  0.608696  0.594642   59.464249  0.019874   1.987417
# 3       NADPH  0.968175  0.976285  0.972230   97.223003  0.005734   0.573401
# 4     Control  0.242767  0.197628  0.220198   22.019789  0.031918   3.191800

# %%
donadores = ["Glucose","Sodium acetate","Lactose","NADPH", "No electron donor"]
plt.figure()
bars = plt.bar(donadores,electron["Porcentaje"],width=0.8,align='center', linewidth=0, color='lightslategrey',yerr=electron['Desv est'])
bars[3].set_color('#1F77B4')

ax = plt.gca()
ax.set_xlabel('Electron Donor', fontsize=12)
ax.set_ylabel('Chromium Reduction (%)', fontsize = 12)
#ax.set_title('Chromium reduction in the presence of electron donors', fontsize = 15)
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
    
ax.set_ylim(0,120)

plt.hlines(101,3,4, colors = 'black')
plt.vlines(3,99,101, colors = 'black')
plt.vlines(4,99,101, colors = 'black')
ax.text(3.5,101,'*')

plt.hlines(106,2,4, colors = 'black')
plt.vlines(2,104,106, colors = 'black')
plt.vlines(4,104,106, colors = 'black')
ax.text(3,106,'**')

plt.hlines(111,1,4, colors = 'black')
plt.vlines(1,109,111, colors = 'black')
plt.vlines(4,109,111, colors = 'black')
ax.text(2.5,111,'***')

plt.hlines(116,0,4, colors = 'black')
plt.vlines(0,114,116, colors = 'black')
plt.vlines(4,114,116, colors = 'black')
ax.text(2,116,'****')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(2, 116, '****')

# %%
muestra = ["Intracelullar Fraction","Membrane Fraction"]
fractions = pd.read_csv("fractions.csv")
plt.figure()
bars = plt.bar(muestra,fractions["Cr Reduction"],width=0.8,align='center', linewidth=0, color='lightslategrey',yerr=fractions['SD'])
bars[0].set_color('#1F77B4')

ax = plt.gca()
#ax.set_xlabel('Electron Donor', fontsize=12)
ax.set_ylabel('Chromium Reduction(%)', fontsize = 13)
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=17)
ax.set_ylim(0,40)

plt.hlines(37,0,1,colors = 'black')
plt.vlines(0,35.5,37, colors='black')
plt.vlines(1,35.5,37, colors = 'black')
ax.text(0.5,37,'*')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 37, '*')

# %%
growth = pd.read_csv("growth_pH.csv")
growth
# Out:
#    pH    Abs1    Abs2    Abs3  Promedio      Desv
# 0  10  0.5240  0.5470  0.6600  0.577000  0.072794
# 1   8  0.2650  0.2100  0.1975  0.224167  0.035911
# 2   7  0.1950  0.0450  0.0795  0.106500  0.078560
# 3   6  0.0165  0.0670  0.0350  0.039500  0.025549
# 4   5  0.0195  0.0245  0.0230  0.022333  0.002566

# %%
plt.figure()
bars = plt.bar(growth['pH'],growth['Promedio'],width=0.8,align='center', linewidth=0, color='lightslategrey',yerr=growth['Desv'])
bars[1].set_color('#1F77B4')

ax = plt.gca()
ax.set_xlabel('pH')
ax.set_ylabel('Reduction Percentage')
ax.set_title('Chromium Reduction at different pH levels')
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
# Out:
# <img src="data:image/png;base64,..." width="640">
